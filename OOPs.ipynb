# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitha-jasp/My-Research/blob/master/OOPs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Agenda**
#
# **1. Introduction to OOPs**
# - Key Concepts in OOPs
# - Creating a Class
# - Defining Class Attributes
#   - Defining Class Attributes Method 1: Without `__init__`
#   - Defining Class Attributes Method 2: Using `__init__`
# - Dunder Methods
#   - Dunder Methods: String Representation of Objects
#   - Other Dunder Methods (contd.)
# - Defining Methods for Classes
#   - Implicit Self
#   - Explicit Self
# - Instance Variables vc Class Varaibles
#
# **2. Pillars of OOPs**
# - Inheritance
#   - `super()` Function
#   - Multiple Inheritance
# - Encapsulation
#   - Public Varaibles
#   - Protected Varaibles
#   - Private Varaibles
# - Abstraction
#   - Abstract Class
#   - Interface
# - Polymorphism
#   - Method Overriding
#     - What is Duck Typing?
#   - Method Overloading
#     - Using Default Parameter Values
#     - Using Variable-Length Argument Lists

# %% [markdown]
# # Introduction to OOPS
#
# * Object-Oriented Programming (OOP) is a programming paradigm that organizes code into reusable units called **objects**, which are desgined from a blueprint called **class**. Each object has its own **properties** and **functions** which are used as an intuitive way to model real-world entities.
#
# ![oops1.png](data:image/png;base64,...)
#
# **Why OOPs is Essential:**
#
# 1. **Modularity:** Encourages code organization into manageable, self-contained units (objects), easing maintenance and updates.
#
# 2. **Reusability:** Objects and classes can be reused in different parts of the code, reducing redundancy and promoting efficient development.
#
# 3. **Abstraction:** Abstracts complex systems into understandable models, making it easier for developers to conceptualize and work with.
#
# 4. **Scalability:** Supports the development of large, complex systems by providing a structured and scalable approach to design.
#
# 5. **Flexibility:** Enables the adaptation of code to changing requirements through features like polymorphism and inheritance.
#
# 6. **Collaboration:** Facilitates teamwork by allowing different developers to work on different components of a project independently.
#
# 7. **Code Maintenance:** Enhances code maintainability by localizing changes to specific classes or objects, minimizing the impact on the overall system.

# %% [markdown]
# ## Key Concepts in OOPs
#
# 1. **Class:** A blueprint or template for creating objects.
#
# 2. **Object/Instance:** A concrete instance of a class.
#
# 3. **Properties:** Attributes that belong to an object.
#
# 4. **Methods:** Functions that define the behaviour of an object.
#
# ![oopscar.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## Creating a Class
#
#
# * InPython, creating a class is straightforward. Use the **class keyword**, followed by the class name, and a colon. Inside the class, define attributes and methods.

# %%
# Creation of a class
class Student:
    pass

# %% [markdown]
# **The pass Keyword in Python Classes**
#
# * Indicates an empty block of code. Useful when a class structure is required without additional functionality.

# %%
# Instantiating a class -> Creating an object of a class
s1 = Student()
s2 = Student()

# %%
# variables in Python such as S1 hold references to objects, not the objects themselves

# %%
print(s1) # printing S1 displays the memory address where the object is stored
print(s2)

# %%
print(type(s1))
print(type(s2))
# Out:
# <class '__main__.Student'>
# <class '__main__.Student'>

# %%
# The id() function in Python provides a unique identifier for an object, and this identifier is often the object's memory address, but it's not guaranteed to be.
id(s1) == id(s2)
# Out:
# False

# %%
a = 5
b= 5
a=6
a=5
print(id(a))
print(id(b))
# Out:
# 4347749720
# 4347749720

# %%
a==b
# Out:
# True

# %%
print(id(s1))
print(id(s2))
# Out:
# 4410523280
# 4410559696

# %% [markdown]
# ## Defining Class Attributes
#
# In Python, there are two main methods of defining class attributes: using `__init__` and directly within the class body. These methods are often referred to as:
#
# 1. **Using `__init__`:**
#    - **Method Name:** `__init__` (short for "initializer").
#    - **Usage:** Attributes are defined and initialized within the `__init__` method.
#
# 2. **Without `__init__`:**
#    - **Usage:** Attributes are defined directly within the class body.

# %% [markdown]
# ### **Defining Class Attributes Method 1 : Without `__init__`:**
#    - **Usage:** Attributes are defined directly within the class body.
#    - **Example:**
#      ```python
#      class MyClass:
#          attribute1 = value1
#          attribute2 = value2
#      ```
#    - **Initialization:** The attributes are set when the class is defined, and their values are shared among all instances of the class.

# %%
s1.name = "Mansi"

# %%
s1.name
# Out:
# 'Mansi'

# %%
s2.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 s2.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
# In the provided code, an attribute error occurs when trying to access s2.name because the name attribute has only been assigned to the s1 object.
# In Python, each object instance maintains its own set of attributes.
# When you set s1.name = "Mansi", it doesn't automatically create the name attribute for all instances of the Student class, including s2.

#To resolve this issue, you should either initialize the name attribute for all instances within the class definition or explicitly assign it to each instance.

# %%
# Resolving the issue by changing the class defintion (explicitly assigning for each object will become redundant)
class Student:
    name = "Akash"  # Default value for the 'name' attribute

# %%
# Multiple instances s1, s2 etc can be created from a class template
#Initially, all instances may have identical attributes unless explicitly changed
s1 = Student()
s2 = Student()

# %%
print(s1.name)  # default value as we didn't expicitly change the name value
print(s2.name)
# Out:
# Akash
# Akash

# %%
s1.name = "Mannu"
print(s1.name)
s2.name= "Tannu"
print(s2.name)  # Output: None
# Out:
# Mannu
# Tannu

# %%
# Adding more attributes
class Student:
    name = None  # Default value for the 'name' attribute
    age = 0      # Default value for the 'age' attribute
    grade = 'A'  # Default value for the 'grade' attribute

# %%
s1=Student()
attributes = {'name': s1.name, 'age': s1.age, 'grade': s1.grade}
print(attributes)
# Out:
# {'name': None, 'age': 0, 'grade': 'A'}

# %% [markdown]
# **Using `vars()` function**
#
# - **`vars()` Function:**
#   - **Purpose:** Returns the `__dict__` attribute of an object, providing a dictionary of its attributes and their current values.
#   - **Usage:** `vars(object)`
#   - **Output Format:** A dictionary containing the object's attributes and their values.
#
# - **Object State:**
#   - **Dynamic Reflection:** `vars()` dynamically reflects the current state of the object, not the default values defined in the class.
#
# - **Instance-Specific Values:**
#   - **Attribute Values:** The returned dictionary includes the current values assigned to the attributes for a specific instance.
#
# - **Modification Tracking:**
#   - **Real-Time Updates:** As attributes are modified during the program's execution, subsequent calls to `vars()` capture these changes, making it useful for real-time inspection.
#
# - **No Default Values:**
#   - **Exclusion of Defaults:** `vars()` does not include default values specified in the class definition; it focuses on the instance's modified attribute values.
#
# - **Alternative Access for Defaults:**
#   - **Direct Class Reference:** To access default values, one can directly refer to the class attributes without creating an instance, providing a separate way to obtain initial attribute values.

# %%
s1 = Student()
s1.name = "Mansi"
s1.age = 20
attributes = vars(s1)
print(attributes) # In this output won't show the grade attribute as it hasn't been modified and still contains default value
# Out:
# {'name': 'Mansi', 'age': 20}

# %%
s1.grade= "B"
attributes = vars(s1)
print(attributes)
# Out:
# {'name': 'Mansi', 'age': 20, 'grade': 'B'}

# %% [markdown]
# ### **Defining Class Attributes Method 2 : Using `__init__`:**
#    - **Method Name:** `__init__` (short for "initializer").
#    - **Usage:** Attributes are defined and initialized within the `__init__` method.
#    - **Example:**
#      ```python
#      class MyClass:
#          def __init__(self, attribute1, attribute2):
#              self.attribute1 = attribute1
#              self.attribute2 = attribute2
#      ```
#    - **Initialization:** Occurs when a new instance of the class is created.
#
# **Difference:**
# - The key difference lies in when and how attributes are initialized.
# - **Using `__init__`:** Allows customization of attribute values during the creation of each instance. Provides flexibility in setting different values for each object.
# - **Without `__init__`:** Sets default values that are shared among all instances of the class. Values are assigned when the class is defined, not when an instance is created..

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age
# The __init__ method takes self (which represents the instance being created) along with name and age as parameters.
# The method initializes the name and age attributes of the Person class.

# %% [markdown]
# **The self Keyword:**
#
# * Represents the instance on which a method is called.
# * Allows access to the instance's attributes and methods.

# %%
# Creating an instance of the class
person1 = Person("Alice", 25)

# Accessing attributes
print(person1.name)
print(person1.age)

# %% [markdown]
# * **Parameters:** These are the variables listed in the function/method definition. They act as placeholders for the values that will be passed during the function/method call. Parameters are specified in the function/method signature.
#
# * **Arguments:** These are the actual values that are passed to a function/method when it is called. They correspond to the parameters of the function/method. Arguments are the values provided in the function/method call.

# %%
person2 = Person("Nimisha")

# %% [markdown]
# **TypeError: Person.__init__() missing 1 required positional argument: 'age'**
#
# * **Missing Argument Error:** This error occurs when you call a function or method that requires certain parameters, but you haven't provided the required values (arguments) during the call.
#
# * **Required Positional Argument:** This phrase specifies that the missing argument is a positional argument, meaning its value is determined by its position in the function/method call, as opposed to keyword arguments where you explicitly mention the parameter name along with the value.The term "positional" emphasizes that the order of the arguments matters.

# %%
class Dog:
    def __init__(self, name, age=1): # If no value for age is given then default value for it will be 1
        self.name = name
        self.age = age

# %%
# Creating multiple instances
dog1 = Dog("Buddy") # not specifying age
dog2 = Dog("Max", age=3) #specifying age

print(dog1.name, dog1.age)
print(dog2.name, dog2.age)

# %% [markdown]
# ## Dunder Methods
#
# ![magic methods.png](data:image/png;base64,...)

# %% [markdown]
# ### Dunder Methods: String Representation of Objects
#
# The `__str__` method in Python is a special method used to provide a meaningful string representation of an object.
#
# ***When you use the built-in `str()` function or `print()` function on an object, Python invokes the `__str__` method if it is defined for that object.***
#
# - **Purpose:**
#   - Defines the human-readable string representation of an object.
#   - Intended for display purposes or creating meaningful output for end-users.
#
# - **Naming Convention:**
#   - The method name is double-underscored (`__str__`), indicating its special status.
#
# - **Syntax:**
#   - ```python
#     def __str__(self):
#         # return a string representation of the object
#     ```
#
# - **Usage:**
#   - When you use `str(obj)` or `print(obj)`, Python looks for the `__str__` method in the object's class to obtain the string representation.
#
# - **Fallback to `__repr__`:**
#   - If `__str__` is not defined, Python falls back to the `__repr__` method for obtaining a string representation.

# %%
class Car:
    def __init__(self, name, mileage):
        self.name = name
        self.mileage = mileage

# %%
c1 = Car("Nexon", 12)
c2 = Car("Altroz", 15)

# %%
print(c1) # Can I override the print behavior?

# %%
class Bike:
    def __init__(self, name , model):
        self.name = name
        self.model = model

    def __str__(self):
        return f"{self.name} with the model : {self.model}"

# %%
b1 = Bike("Pulsar", "T67")
b2 = Bike("Royal", "Thunder")

# %%
print(b1)
# Out:
# Pulsar with the model : T67

# %%
class Car:
    def __init__(self, name, mileage):
        self.name = name
        self.mileage = mileage

    # __str__ magic method to override print behavior
    def __str__(self):
        return f"{self.name} has the mileage: {self.mileage}"

# %%
c1 = Car("Nexon", 12)
c2 = Car("Altroz", 15)

# %%
print(c1)
# Out:
# Nexon has the mileage: 12

# %%
print(c2)
# Out:
# Altroz has the mileage: 15

# %%
class ComplexNumber:
    def __init__(self, real, imaginary):
        self.real = real
        self.imaginary = imaginary

    # overrides the print behavior of printing object of class ComplexNumber
    def __str__(self):
        return f"{self.real} + i{self.imaginary}"

# %%
c1 = ComplexNumber(5, 3)

# %%
print(c1)
# Out:
# 5 + i3

# %%
print(c1.real)
# Out:
# 5

# %%
c2 = ComplexNumber(3, 6)
print(c2)
# Out:
# 3 + i6

# %% [markdown]
# ### Other Dunder Methods (contd.)
#
# | Dunder Name   | Description                                                                                       |
# |---------------|---------------------------------------------------------------------------------------------------|
# | `__init__`    | Initializes an instance of a class.                                                               |
# | `__str__`     | Defines the human-readable string representation of an object when using `str(obj)` or `print(obj)`. |
# | `__repr__`    | Defines the official string representation of an object, used by `repr(obj)`.                       |
# | `__add__`     | Defines the behavior of the addition operator (`+`) for instances of a class.                       |
# | `__call__`    | Allows an instance of a class to be called as if it were a function.                                |
# | `__getitem__` | Enables the use of square bracket notation (`obj[key]`) to retrieve items from an object.           |
# | `__setitem__` | Enables the use of square bracket notation (`obj[key] = value`) to set items in an object.          |
# | `__len__`     | Specifies the length of an object, used by the `len()` function.                                    |
# | `__eq__`      | Defines the behavior of the equality operator (`==`) for instances of a class.                      |
# | `__ne__`      | Defines the behavior of the inequality operator (`!=`) for instances of a class.                   |

# %% [markdown]
# - **Method Name:** `__add__`
# - **Purpose:** Defines the behavior of the addition operator (`+`) for instances of a class.
# - **Usage:** Defined within the class, it takes two parameters: `self` (representing the instance) and another object to be added.
# - **Syntax:**
#   ```python
#   def __add__(self, other):
#       # define the addition behavior
#   ```

# %% [markdown]
# - **Method Name:** `__call__`
# - **Purpose:** Defines the behavior of calling instances of a class as if they were functions.
# - **Usage:** Defined within the class, it takes at least one parameter (`self`), representing the instance being called, and can take additional parameters.
# - **Syntax:**
#   ```python
#   def __call__(self, *args, **kwargs):
#       # define the behavior when the instance is called
#   ```

# %%
class Car:
    def __init__(self, name, milaege):
        self.name = name
        self.milaege = milaege

    def __str__(self):
        return f"{self.name} -> {self.milaege}"

    def __add__(self, other):
        return self.name + other.name

    def __call__(self):
        return "I JUST GOT CALLED WOHOOOOO!!!"

# %%
c1 = Car("Nexon", 13)
c2 = Car("Altroz", 15)

# %%
print(c1)
# Out:
# Nexon -> 13

# %%
print(c1())
# Out:
# I JUST GOT CALLED WOHOOOOO!!!

# %%
print(c1+c2)
# Out:
# NexonAltroz

# %%
{3,4} + {4,5}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-7f44b22a6986> in <cell line: 1>()
# ----> 1 {3,4} + {4,5}
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
c1 + c2
# c1.__add__(c2)
# Car.__add__(c1,c2)
# Out:
# 'NexonAltroz'

# %%
Car.__add__(c1,c2)
# Out:
# 'NexonAltroz'

# %%
c1()
# Out:
# 'I JUST GOT CALLED WOHOOOOO!!!'

# %% [markdown]
# ## Defining Methods for Classes

# %%
class Dog:
  def __init__(self, name, breed):
    self.name=name
    self.breed=breed

  def intro(self):
    print(f"Hello my name is {self.name}, bhau bhau")

# %%
d1=Dog("Togo", "Shitzu")

# %% [markdown]
# ### Implicit Self:
#
# * Implicit self is the default and more commonly used approach.
#
# * When a method is called through an instance, Python automatically passes the instance as the first argument (referred to as self conventionally).

# %%
d1.intro()
# Out:
# Hello my name is Togo, bhau bhau

# %% [markdown]
# ### Explicit Self:
#
# * Explicit self usage involves calling a method using the class itself and explicitly passing the instance as an argument.
#
# * While less common, it provides clarity on the role of self as a placeholder for the instance.

# %%
Dog.intro(d1)
# Out:
# Hello my name is Togo, bhau bhau

# %% [markdown]
# ## Instance Variables vs Class Variables
#
# ![classinstance.png](data:image/png;base64,...)

# %% [markdown]
# | Aspect                      | Instance Variables                                           | Class Variables                                |
# |-----------------------------|--------------------------------------------------------------|------------------------------------------------|
# | **Scope**                   | Belong to an instance of the class.                          | Shared among all instances of the class.       |
# | **Declaration**             | Defined inside the constructor (`__init__`) or methods.      | Defined outside methods, directly in the class. |
# | **Access**                  | Accessed using the instance of the class.                    | Accessed using the class name.                  |
# | **Modification**            | Changes affect only the specific instance.                  | Changes affect all instances of the class.     |
# | **Initialization**          | Initialized in the constructor (`__init__`) or methods.      | Initialized outside methods, in the class body.|
# | **Use Case**                | Represents characteristics unique to each instance.         | Represents characteristics shared by all instances.|
# | **Memory Location**         | Different memory locations for each instance.                | Shared memory location among all instances.    |
# | **Example**                 | ```python class MyClass: def __init__(self, var): self.var = var``` | ```python class MyClass: class_var = "shared"``` |

# %%
class Student:
    batch_name = 'Dec24' # Class Variable

    def __init__(self, name, age):
        # Instance Variable
        self.name = name
        self.age =age

s1 = Student("Akash", 30)
print(s1.name)
print("BEFORE CHANGING")
print(s1.batch_name)

s1.batch_name = "Jan_2025"
print("AFTER CHANGING")
print(s1.batch_name)
# Out:
# Akash
# BEFORE CHANGING
# Dec24
# AFTER CHANGING
# Jan_2025

# %%
s2 = Student("Alice" , 23)
s2.batch_name
# Out:
# 'Dec24'

# %%
Student.batch_name
# Out:
# 'Dec24'

# %%
class Vehicle:
    vehicle_type= 'Car' # Class Variable
    def __init__(self, name, age):
        self.name = name
        self.age =age

s1 = Vehicle("Chayan", 30)
print(s1.name)
print(s1.vehicle_type)
# Out:
# Chayan
# Car

# %%
s2 = Vehicle("Chayean", 340)
print(s2.name)
print(s2.vehicle_type)
# Out:
# Chayean
# Car

# %%
print(id(Vehicle.vehicle_type)) # Since batch_name is a class variable so it's memory location is same for all objects
print(id(s1.vehicle_type))
print(id(s2.vehicle_type))
# Out:
# 4427473648
# 4427473648
# 4427473648

# %%
print(id(s1.name)) # # Since name is an instance variable so it's memory location is different for all objects
print(id(s2.name))
# Out:
# 139845822990576
# 139845823004528

# %%
# Updating Class Variable
Student.batch_name = "May22"

# %%
# Changes in Class Variable in all objects of that class
print(s1.batch_name)
print(s2.batch_name)
# Out:
# May22
# May22

# %%
# Q: What if I create/update class variable using object instead of class
# a: A new instance variable will be created belonging to only the object that tried to update the attribute

# %%
s1.batch_name = 'June22'

# %%
print(s1.name, s1.batch_name)
# Out:
# Chayan June22

# %%
print(s2.name, s2.batch_name)
# Out:
# Needa May22

# %%
Student.batch_name
# Out:
# 'May22'

# %%
s3=Student("Poppy", 56)
print(s3.batch_name)
# Out:
# May22

# %%
attributes = vars(s1)
print(attributes) # New Instance Variable Created only for s1
# Out:
# {'name': 'Chayan', 'age': 30, 'batch_name': 'June22'}

# %%
#Note: If class_variable and instance_variable both have same attribute_name, accessing using object would get instance variable

class Student:
    # Class variable
    batch = 'June22'

    def __init__(self, name, batch='May22'):
        # Instance variables
        self.name = name
        self.batch = batch

    def get_person_name(self):
        print(self.name)

# Creating instances
p1 = Student("Needa")
p2 = Student("Chayan")

# Modifying the batch attribute for p2 (instance variable)
p2.batch = 'July22'

# # Accessing the batch attribute using class name, p1, and p2
print("Class Batch:", Student.batch)   # (Accessing class variable)
print("p1 Batch:", p1.batch)           # (Accessing instance variable)
print("p2 Batch:", p2.batch)           # (Accessing modified instance variable)
# Out:
# Class Batch: June22
# p1 Batch: May22
# p2 Batch: July22

# %% [markdown]
# # Pillars of OOPs

# %%
super().
# Out:
#   File "<ipython-input-45-7a177835b4ac>", line 1
#     super().
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# 1. **Encapsulation:**
#    - **Definition:** Encapsulation is the bundling of data (attributes) and the methods (functions) that operate on that data into a single unit known as a class.
#    - **Purpose:** It helps in hiding the internal state of an object and requiring all interactions to be performed through an object's methods. This concept aids in data protection and organization.
#
# 2. **Inheritance:**
#    - **Definition:** Inheritance is a mechanism in object-oriented programming that allows a new class (subclass or derived class) to inherit attributes and behaviors from an existing class (superclass or base class).
#    - **Purpose:** Inheritance promotes code reuse, extensibility, and the creation of a hierarchy of classes. Subclasses inherit attributes and methods from their superclass, reducing redundancy in code.
#
# 3. **Polymorphism:**
#    - **Definition:** Polymorphism refers to the ability of different objects to be treated as instances of the same class through a common interface.
#    - **Purpose:** Polymorphism enhances flexibility and extensibility. It allows for the creation of code that can work with objects of various types, leading to more modular and reusable code.
# 4. **Abstraction**:
#
#   - **Definition**: Data abstraction is a fundamental concept in object-oriented programming that involves simplifying complex systems by modeling classes based on the essential properties and behaviors relevant to the system while hiding unnecessary details.
#
#   - **Purpose**: The primary purpose of data abstraction is to provide a clear separation between the abstract representation of an object and the way it is implemented. It allows programmers to focus on the essential features of an object, promoting a high level of modularity and reducing complexity.

# %% [markdown]
# ## Inheritance
#
# ![inheritance.png](data:image/png;base64,...)

# %% [markdown]
# **Key Terms**
#
# 1. **Inheritance:** A mechanism in object-oriented programming where a new class (subclass or derived class) inherits attributes and behaviors from an existing class (superclass or base class).
# 2. **Superclass:** The existing class from which attributes and methods are inherited by a new class. Also known as a base class or parent class.
# 3. **Subclass:** The new class that inherits attributes and methods from an existing class. Also known as a derived class or child class.
# 4. **Base Class:** Another term for a superclass, indicating the class from which other classes inherit.
# 5. **Derived Class:** Another term for a subclass, indicating the class that inherits from another class.

# %% [markdown]
# The syntax for inheritance in Python involves creating a subclass that inherits from a superclass.
#
# ```python
# class Superclass:
#     # Superclass attributes and methods
#
# class Subclass(Superclass):
#     # Subclass attributes and methods
# ```
#
# Explanation of the syntax:
#
# - `class Superclass:`: This line defines the superclass.
# - `class Subclass(Superclass):`: This line defines the subclass, and the `(Superclass)` indicates that the subclass inherits from the superclass.

# %%
class Animal:
    def __init__(self, species):
        self.species = species

    def eat(self):
        print("I am eating!!!")

# %%
class Cat(Animal):
    def __init__(self, name):
        # To set specific data for the Cat, we need to call the Animal initializer
        # Using Animal.__init__(self, "Cat") invokes the constructor of the Animal superclass
        # This ensures that the 'species' attribute of the Cat is initialized to "Cat"
        Animal.__init__(self, "Cat")

        # super().__init__("Cat")

        # Now, we can set the 'name' attribute specific to the Cat subclass
        self.name = name

    def speak(self):
        print("Meoooewww Meooow!!!!")

# %%
class Dog(Animal):
    def __init__(self, name):
        Animal.__init__(self, "Dog")
        self.name = name

    def speak(self):
        print("Boooow Bhhoowww!!!!")

# %%
c = Cat("Tom")
print(c.name)
print(c.species)
# Out:
# Tom
# Cat

# %%
c.speak()
# Out:
# Meoooewww Meooow!!!!

# %%
c.eat()
# Out:
# I am eating!!!

# %%
d = Dog("Scooby Doo")

# %%
print(d.name)
print(d.species)
# Out:
# Scooby Doo
# Dog

# %%
d.speak()
# Out:
# Boooow Bhhoowww!!!!

# %%
d.eat()
# Out:
# I am eating!!!

# %% [markdown]
# ### `super()` Function
#
# In Python, `super()` is a built-in function that is used to call a method from a superclass.
#
# - **Method Resolution Order (MRO):**
#   - In Python, when a method is called, the interpreter searches for it in the current class. If not found, it looks in the superclass, then in the superclass of the superclass, and so on. This order is known as the Method Resolution Order (MRO).
#   - `super()` helps maintain the MRO by allowing a subclass to invoke a method from its superclass.
#
# **Syntax:**
# ```python
# class Subclass(Superclass):
#     def some_method(self):
#         super().some_method()  # Call the same method from the superclass
# ```
#
# - `super()` returns a temporary object of the superclass, allowing you to call its methods.
# - It is often used inside a method in a subclass to call the corresponding method in the superclass.
# - `super()` without arguments is equivalent to `super(__class__, self)` where `self` is the instance of the subclass.

# %%
class Animal:
    def __init__(self, species):
        self.species = species
        print('self inside Animal class:')
        print(self)

    def eat(self):
        print("I am eating!!!")

# %%
# Animal-- superClass

Animal.__init__(self,"Cat")

super().__init__("Cat")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-7bd3fde83360> in <cell line: 1>()
# ----> 1 Animal-- superClass
#       2
#       3 Animal.__init__(self,"Cat")
#       4
#       5 super().__init__("Cat")
#
# NameError: name 'superClass' is not defined

# %%
class Cat(Animal): # syntax to inherit
    def __init__(self, name):
        print('self inside Cat class:')
        print(self)
        super().__init__("Cat") # the object is passed automatically
        self.name = name

    def speak(self):
        print("Meoooewww Meooow!!!!")

# %%
c = Cat("Tom")
print(c.name)
# Out:
# self inside Cat class:
# ...
# self inside Animal class:
# ...
# Tom

# %%
class Cat(Animal): # syntax to inherit
    def __init__(self, name):
        print('self inside Cat class:')
        print(self)
        super().__init__("Cat") # the object is passed automatically
        self.name = name

    def speak(self):
        print("Meoooewww Meooow!!!!")

# %%
c = Cat("Tom")
print(c.name)
# Out:
# self inside Cat class:
# ...
# self inside Animal class:
# ...
# Tom

# %%
print(c.species)
# Out:
# Cat

# %% [markdown]
# 1. Single Inheritance
# In single inheritance, a subclass inherits from exactly one superclass. This is the simplest form of inheritance.
#
# Example:
#
# Consider a base class Vehicle and a subclass Car that inherits from Vehicle.

# %%
class Vehicle:
    def __init__(self, brand, model):
        self.brand = brand
        self.model = model

    def displayInfo(self):
        print(f"Vehicle Brand: {self.brand}, Model: {self.model}")

class Car(Vehicle):
    def __init__(self, brand, model, car_type):
        super().__init__(brand, model)
        self.car_type = car_type

    def displayCarInfo(self):
        self.displayInfo()
        print(f"Car Type: {self.car_type}")

# Usage
my_car = Car("Toyota", "Corolla", "Sedan")
my_car.displayCarInfo()
# Out:
# Vehicle Brand: Toyota, Model: Corolla
# Car Type: Sedan

# %% [markdown]
# 2. Multilevel Inheritance
# In multilevel inheritance, a class inherits from a subclass, making it a subclass of the second class, and so on. It forms a "grandparent-parent-child" relationship.
#
# Example:
#
# Vehicle -> Car -> ElectricCar

# %%
class ElectricCar(Car):
    def __init__(self, brand, model, car_type, battery_size):
        super().__init__(brand, model, car_type)
        self.battery_size = battery_size

    def displayElectricCarInfo(self):
        self.displayCarInfo()
        print(f"Battery Size: {self.battery_size} kWh")

# Usage
my_electric_car = ElectricCar("Tesla", "Model S", "Sedan", 100)
my_electric_car.displayElectricCarInfo()
# Out:
# Vehicle Brand: Tesla, Model: Model S
# Car Type: Sedan
# Battery Size: 100 kWh

# %% [markdown]
# 3. Hierarchical Inheritance
# In hierarchical inheritance, multiple subclasses inherit from a single superclass. This allows different child classes to share the same base class.
#
# Example:
#
# Vehicle -> Car and Vehicle -> Truck

# %%
class Truck(Vehicle):
    def __init__(self, brand, model, load_capacity):
        super().__init__(brand, model)
        self.load_capacity = load_capacity

    def displayTruckInfo(self):
        self.displayInfo()
        print(f"Load Capacity: {self.load_capacity} tons")

# Usage
my_truck = Truck("Ford", "F-150", 2)
my_truck.displayTruckInfo()
# Out:
# Vehicle Brand: Ford, Model: F-150
# Load Capacity: 2 tons

# %% [markdown]
# Hybrid inheritance combines two or more types of inheritance. In Python, this often means combining single, multiple, hierarchical, and/or multilevel inheritance. Below is an example that demonstrates hybrid inheritance by integrating multiple and hierarchical inheritance.
#
# In this example, we'll create a simple class structure that represents a school system. We will have a Person class from which Teacher and Student classes inherit, demonstrating hierarchical inheritance. Additionally, we'll introduce a ClubMember class that is not directly related to the Person class hierarchy. Then, we'll create a ClubPresident class that inherits from both Student and ClubMember, showcasing multiple inheritance

# %%
# Base class for a person in the school
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def displayPerson(self):
        print(f"Name: {self.name}, Age: {self.age}")

# Derived class from Person
class Student(Person):
    def __init__(self, name, age, student_id):
        super().__init__(name, age)
        self.student_id = student_id

    def displayStudent(self):
        self.displayPerson()
        print(f"Student ID: {self.student_id}")

# Another derived class from Person
class Teacher(Person):
    def __init__(self, name, age, subject):
        super().__init__(name, age)
        self.subject = subject

    def displayTeacher(self):
        self.displayPerson()
        print(f"Subject: {self.subject}")

# Base class for a club member
class ClubMember:
    def __init__(self, club_name):
        self.club_name = club_name

    def displayClubMember(self):
        print(f"Club: {self.club_name}")

# Derived class from Student and ClubMember (Multiple Inheritance)
class ClubPresident(Student, ClubMember):
    def __init__(self, name, age, student_id, club_name):
        Student.__init__(self, name, age, student_id)
        ClubMember.__init__(self, club_name)

    def displayPresident(self):
        self.displayStudent()
        self.displayClubMember()
        print("Role: President")

# Usage
president = ClubPresident("Alex", 20, "S123", "Science Club")
president.displayPresident()
# Out:
# Name: Alex, Age: 20
# Student ID: S123
# Club: Science Club
# Role: President

# %% [markdown]
# Hierarchical Inheritance: Both Student and Teacher inherit from Person. This demonstrates a hierarchical structure where Student and Teacher are at the same level in the hierarchy, both being types of Person.
#
#
# Multiple Inheritance: The ClubPresident class inherits from both Student and ClubMember. This demonstrates multiple inheritance since ClubPresident combines behaviors and properties from two distinct parent classes.
#
#
# This hybrid approach allows for flexible and powerful class hierarchies, enabling the creation of complex relationships between objects. However, it's essential to use multiple inheritance carefully to avoid complexity and maintain readability and maintainability of the code.

# %% [markdown]
# ### Multiple Inheritance
# * In Python, multiple inheritance is a feature that allows a class to inherit attributes and methods from more than one superclass. This enables a subclass to inherit and combine functionalities from multiple sources.
#
# ![types of inheritance.webp](data:image/webp;base64,...)

# %% [markdown]
# ## Encapsulation

# %% [markdown]
# **Key Terms**
#
# 1. **Encapsulation:** The bundling of data (attributes) and methods (functions) that operate on that data into a single unit known as a class. Encapsulation helps in restricting access to some of an object's components.
# 2. **Access Modifiers:** Keywords or conventions in a programming language that specify the visibility and accessibility of attributes or methods. In Python, the use of underscores (`_` and `__`) is a convention for indicating variable visibility.
# 7. **Public Variable:** A class attribute or method that is accessible from outside the class. Public variables do not have names prefixed with double underscores.
# 4. **Private Variable:** A class attribute or method that is hidden from external access by prefixing its name with a double underscore (`__`). Private variables are accessible and modifiable only within the class.
# 7. **Protected Variable:** A class attribute or method that is indicated as protected by convention by prefixing its name with a single underscore (`_`). While it is still accessible from outside the class, it signals that it is intended for internal use or for use by subclasses.
# 5. **Getter and Setter Methods:** Methods within a class designed to get (`getters`) or set (`setters`) the values of private variables. They provide controlled access to private attributes.

# %% [markdown]
# ![convention.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![tableaccess.png](data:image/png;base64,...)

# %% [markdown]
# ### Public Variables

# %%
class Car:
    def __init__(self, make, model, year):
        # Public variables
        self.make1 = make
        self.model1 = model
        self.year1 = year

    def display_info(self):
        print(f"{self.year1} {self.make1} {self.model}")

# Creating an instance of the Car class
my_car = Car("Toyota", "Camry", 2022)

# Accessing and modifying public variables
print(f"Make: {my_car.make}")
print(f"Model: {my_car.model}")
print(f"Year: {my_car.year}")

# Modifying a public variable
my_car.year = 2023

# Displaying updated information
my_car.display_info()
# Out:
# Make: Toyota
# Model: Camry
# Year: 2022
# 2023 Toyota Camry

# %%
my_car.display_info()
my_car.year
# Out:
# 2023 Toyota Camry
# 2023

# %% [markdown]
# * In Python, variables without any underscore prefix are considered public by convention.
#
# * In this example, `make`, `model`, and `year` are public variables. They are accessible from outside the class, and their values can be easily modified. The `display_info` method demonstrates how to use these public variables to display information about the car.

# %% [markdown]
# ### Protected Variables

# %%
class MyClass:
    def __init__(self):
        self._protected_var = 10
        self.test=100
        self.__test2=1000

    def get_protected_var(self):
        return self._protected_var

    def set_protected_var(self, value):
        if value > 0:
            self._protected_var = value
        else:
            print("Value must be greater than 0.")

# Creating an instance of MyClass
obj = MyClass()

# %%
obj.__test2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 obj.__test2
#
# AttributeError: 'MyClass' object has no attribute '__test2'

# %%
obj.test
# Out:
# 100

# %%
obj._protected_var
# Out:
# 10

# %%
# Accessing the protected variable using a getter method
print("Initial Value:", obj.get_protected_var())

# Modifying the protected variable using a setter method
obj.set_protected_var(20)
print("Modified Value:", obj.get_protected_var())

# Trying to access the protected variable directly (not recommended)
print("Direct Access:", obj._protected_var)
# Out:
# Initial Value: 10
# Modified Value: 20
# Direct Access: 20

# %% [markdown]
# * In Python, a protected variable is conventionally denoted by a single leading underscore (`_`).
#
# * While it doesn't provide strict access control like private variables (those with a double leading underscore), it signals that the variable is intended for internal use and should not be accessed directly from outside the class.
#
# - `_protected_var` is a protected variable within the class `MyClass`.
# - The `get_protected_var` method is a getter method to access the protected variable.
# - The `set_protected_var` method is a setter method to modify the protected variable, but with validation (value must be greater than 0).
# - Direct access to `_protected_var` from outside the class is discouraged, but it's still possible. The convention is to use the getter and setter methods.

# %%
obj._protected_var
# Out:
# 20

# %% [markdown]
# ### Private Variables

# %%
class BankAccount:
    def __init__(self,name ,opening_balance):
        self.name = name
        self.__balance = opening_balance
        # using __ creates a private property (variable)
        # this variable is only accessible by class methods
        # this variable now can't be accessed using class objects

    def withdraw(self, amount):
        self.__balance -= amount

    def deposit(self, amount):
        self.__balance += amount

    def show_balance(self): # getter
        print(self.__balance)

# %%
b2.name

# %%
b2 = BankAccount("akash",10000)

# %%
b2.name
# Out:
# 'akash'

# %%
b2.name = "Amit"
b2.name
# Out:
# 'Amit'

# %%
b2.__balance
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 b2.__balance
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
b2.__balance =200000
b2.__balance
# Out:
# 200000

# %%
b2.show_balance()
# Out:
# 15000

# %%
b2.deposit(5000)

# %%
b2.__balance # Attempting to access __balance directly (will result in an AttributeError)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 b2.__balance
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
b2.balance # Attempting to access __balance directly (will result in an AttributeError)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 b2.balance
#
# AttributeError: 'BankAccount' object has no attribute 'balance'

# %%
b2.show_balance()
# Out:
# 15000

# %%
b2.__balance = 100000

# %%
b2.__balance
# Out:
# 100000

# %%
b2.show_balance()
# Out:
# 15000

# %%
b2.__balance = 123456789098765432123456789876543212345678

# %%
b2.__balance
# Out:
# 123456789098765432123456789876543212345678

# %% [markdown]
# When you attempt to directly set a value to b2.__balance like b2.__balance = 123456789098765432123456789876543212345678, given that __balance is a private attribute of the BankAccount class, Python does not actually modify the original private __balance attribute defined within the class. Instead, what you are doing is creating a new instance attribute for the b2 object, which is distinct from the private __balance attribute used and manipulated by the class methods.

# %%
b2.show_balance()
# Out:
# 15000

# %%
b2.deposit(100000)

# %%
b2._BankAccount__balance
# Out:
# 115000

# %%
b2.withdraw(100000)

# %%
b2._BankAccount__balance # NAME MANGLING
# python adds prefix of _ClassName to private variables
# Out:
# 5000

# %%
b2.withdraw(500)

# %%
b2.show_balance()
# Out:
# 14500

# %% [markdown]
# ## Abstraction

# %% [markdown]
# **Key Terms:**
# * **Simplicity**: The user interacts with a simple interface, unaware of the complex underlying logic.
#
# * **Security**: Sensitive data and operations are hidden from the user.
#
# * **Modularity**: Changes in the abstracted part do not affect the user's interaction with it.

# %% [markdown]
# Two ways to implement Abstraction:-

# %% [markdown]
# #### 1. Abstract Class

# %% [markdown]
# - Key Points:
#  - Abstract class "Shape" with an abstract method calculate_area().
#  - Rectangle and Circle are subclasses providing their implementations.

# %%
# Demonstrates polymorphism.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        return 100

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

# %%
shape1 = Rectangle(5.0, 3.0)
shape2 = Circle(2.5)

# Key Point:
# - Utilizing polymorphism to calculate areas without knowing the concrete types.

print(f"Area of Rectangle: {shape1.calculate_area()}")
print(f"Area of Circle: {shape2.calculate_area()}")
# Out:
# Area of Rectangle: 15.0
# Area of Circle: 19.625

# %% [markdown]
# Abstract Base Class (Shape):
# The Shape class is defined as an abstract base class (ABC) using the ABC module from Python's abc library. This is indicated by subclassing ABC.
# An abstract method calculate_area is declared using the @abstractmethod decorator. This means any subclass of Shape must implement the calculate_area method. However, the implementation in the Shape class (return 100) doesn't follow the typical use of abstract methods, as abstract methods usually don't provide an implementation (they should pass or raise NotImplementedError), serving instead as a template for subclasses to implement.
#
#
# Concrete Classes (Rectangle and Circle):
# Two concrete classes, Rectangle and Circle, inherit from Shape. They are concrete because they provide specific implementations of the abstract method calculate_area.
# Rectangle takes length and width as parameters and calculates the area as length * width.
# Circle takes radius as a parameter and calculates the area as 3.14 * radius * radius (using 3.14 as an approximation of π).
#
#
# Polymorphism:
# Polymorphism is demonstrated here through the ability of Rectangle and Circle to be used interchangeably as Shape objects. Despite their different implementations of calculate_area, both can be treated as Shape instances.
# This allows for writing generic code that can operate on collections of Shape objects, calling the calculate_area method on each, without needing to know the specific type of shape (e.g., Rectangle, Circle, or any other shape that might be added later following the same pattern).

# %%
# Demonstrates polymorphism.
from abc import ABC, abstractmethod

class Shape(ABC):
    @abstractmethod
    def calculate_area(self):
        pass

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    # def calculate_area(self):
    #     return 3.14 * self.radius * self.radius

if __name__ == "__main__":
    shape1 = Rectangle(5.0, 3.0)
    shape2 = Circle(2.5)

    # Key Point:
    # - Utilizing polymorphism to calculate areas without knowing the concrete types.

    print(f"Area of Rectangle: {shape1.calculate_area()}")
    print(f"Area of Circle: {shape2.calculate_area()}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 26
#      24 if __name__ == "__main__":
#      25     shape1 = Rectangle(5.0, 3.0)
# ---> 26     shape2 = Circle(2.5)
#      28     # Key Point:
#      29     # - Utilizing polymorphism to calculate areas without knowing the concrete types.
#      31     print(f"Area of Rectangle: {shape1.calculate_area()}")
#
# TypeError: Can't instantiate abstract class Circle with abstract method calculate_area

# %%
class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return 3.14 * self.radius * self.radius

if __name__ == "__main__":
    shape1 = Rectangle(5.0, 3.0)
    shape2 = Circle(2.5)

    # Key Point:
    # - Utilizing polymorphism to calculate areas without knowing the concrete types.

    print(f"Area of Rectangle: {shape1.calculate_area()}")
    print(f"Area of Circle: {shape2.calculate_area()}")
# Out:
# Area of Rectangle: 15.0
# Area of Circle: 19.625

# %% [markdown]
# #### 2. Interface

# %% [markdown]
# - Key Points:
#  - Interface "Drawable" with an abstract method draw().
#  - Circle class implements the Drawable interface.

# %%
# class Circle(Drawable):
#     def draw(self):
#         print("Drawing a circle.")

# if __name__ == "__main__":
#     drawable = Circle()

#     # Key Point:
#     # - Using an interface to draw without knowing the specific class.

#     drawable.draw()

# %%
# Demonstrates the concept of interfaces in Python
# from abc import ABC, abstractmethod

from abc import ABC, abstractmethod

class Drawable(ABC):
    @abstractmethod
    def draw(self):

        pass

class Circle(Drawable):
    def draw(self):
        print("Drawing a circle.")


drawable = Circle()

# Key Point:
# - Using an interface to draw without knowing the specific class.

drawable.draw()
# Out:
# Drawing a circle.

# %% [markdown]
# ## Polymorphism

# %% [markdown]
# - **Key terms**
#  * Polymorphism, derived from the Greek words "poly" (many) and "morph" (shape).
#
#  * Polymorphism allows objects of different classes to be treated as objects of a common superclass. It's essential for writing flexible and reusable code.

# %% [markdown]
# There are mainly two types of Polymorphism:

# %% [markdown]
# ### 1. Method Overriding
#
# Also known as Run-Time Polymorphism

# %% [markdown]
# Subclasses provide a specific implementation of a method that is already defined in its superclass.
#
# Example:

# %%
class Bird:
    def fly(self):
        return "Some birds can fly"

class Sparrow(Bird):
    def fly(self):
        return "Sparrow flies"

class Ostrich(Bird):
    def fly1(self):
        return "Ostrich cannot fly"

# Usage
sparrow = Sparrow()
ostrich = Ostrich()
print(sparrow.fly())  # Output: Sparrow flies
print(ostrich.fly())  # Output: Ostrich cannot fly
# Out:
# Sparrow flies
# Some birds can fly

# %% [markdown]
# #### What is Duck Typing?
# The famous saying, "If it looks like a duck and quacks like a duck, then it probably is a duck," encapsulates the essence of Duck Typing

# %% [markdown]
# * Duck Typing is a form of run-time polymorphism.
# * **Flexible Type Checking:** Unlike traditional polymorphism, which relies on inheritance hierarchies and interfaces,  Duck Typing allows for more flexible type checking.

# %%
class Bird:
    def fly(self):
        return "This bird can fly"

class Airplane:
    def fly(self):
        return "This airplane can fly"

def test_flying_ability(flying_object):
    print(flying_object.fly())

# Usage
bird = Bird()
airplane = Airplane()
test_flying_ability(bird)        # Output: This bird can fly
test_flying_ability(airplane)    # Output: This airplane can fly
# Out:
# This bird can fly
# This airplane can fly

# %% [markdown]
# ### 2. Method Overloading
# Also known as Compile Time Polymorphism or Parameter Polymorphism

# %% [markdown]
#  #### Using Default Parameter Values

# %% [markdown]
# 1. Default Parameter Values:
#
#  * Define default values for function parameters.
#  * Allows a function to be called with fewer arguments than it is defined to accept.
# 2. Optional Parameters:
#
#  * Parameters with default values become optional.
#  * Provide flexibility in function calls.

# %%
class Calculator:
    def add(self, a, b=0, c=0,d=6):
        return a + b + c +d

# Example Usage:
calc = Calculator()

# Example 1: Adding two numbers
result1 = calc.add(5, 3,1)
print(f"Result 1: {result1}")

# Example 2: Adding three numbers
result2 = calc.add(2, 4, 6)
print(f"Result 2: {result2}")
# Out:
# Result 1: 15
# Result 2: 18

# %%
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.__salary = salary  # Private variable

    def show_salary(self):
        return self.__salary  # Access inside the class

emp = Employee("John", 50000)

print(emp.__salary)  # ❌ AttributeError: 'Employee' object has no attribute '__salary'

# ✅ Accessing private variable using name mangling
print(emp._Employee__salary)  # Output: 50000
# Out:
# 50000

# %%
class Calculator:
    def add(self, a, b=0, c=0,d=6):
        return a + b + c +d

# Example Usage:
calc = Calculator()

# %%
calc.add(5)
# Out:
# 11

# %%
calc.add(5,7 ,1 ,9)
# Out:
# 22

# %%
calc.add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 calc.add()
#
# TypeError: Calculator.add() missing 1 required positional argument: 'a'
