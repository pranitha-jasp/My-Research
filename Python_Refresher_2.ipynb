# %% [markdown]
# <a href="https://colab.research.google.com/github/pranitha-jasp/My-Research/blob/master/Python_Refresher_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Python Refresher-2

# %% [markdown]
# **Agenda**
#
# 1. Pattern Problems
# 2. Built-in Data Structures in Python
#   * Lists
#   * Strings
#   * Tuples
#   * Sets
#   * Dictionaries

# %% [markdown]
# ##Pattern Problems:(Using Nested Loops)

# %% [markdown]
# ###1. Printing Stars in a single row:

# %%
for j in range(5):
    print("*", end='')
# Out:
# *****

# %% [markdown]
# ###2. Printing a pattern of stars with 3 rows and 5 columns

# %%
for j in range(5):
    print("*", end='')

print()

for j in range(5):
    print("*", end='')

print()

for j in range(5):
    print("*", end='')
# Out:
# *****
# *****
# *****

# %% [markdown]
# ###Question 1: Write a program to print a N x M matrix of  *
#
# Example: if N=4, M=2
# Pattern would be:
#
# **
#
# **
#
# **
#
# **

# %%
N = int(input())
M = int(input())

for i in range(N):
    for j in range(M):
        print('*', end='')
    print()
# Out:
# 5
# 6
# ******
# ******
# ******
# ******
# ******

# %% [markdown]
# ###3. Stair Pattern

# %%
N = 5

for i in range(1, N+1):
    for j in range(i):
        print("*", end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ###4. Reverse Stair Pattern

# %%
N = 15

for i in range(1, N+1):
    # For each row, print (N-i+1) cols
    for j in range(N-i+1):
        print('*', end='')
    print()
# Out:
# ***************
# **************
# *************
# ************
# ***********
# **********
# *********
# ********
# *******
# ******
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ###5. Diamond Pattern:

# %%
n = int(input("Enter the number of rows: "))

for i in range(1, n + 1):
    print(" " * (n - i) + "*" * (2 * i - 1))

for i in range(n - 1, 0, -1):
    print(" " * (n - i) + "*" * (2 * i - 1))
# Out:
# Enter the number of rows: 6
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
#  *********
#   *******
#    *****
#     ***
#      *

# %% [markdown]
# ###6. Pyramid Pattern

# %%
n = int(input("Enter the number of rows: "))

for i in range(1, n + 1):
    print(" " * (n - i) + "*" * (2 * i - 1))
# Out:
# Enter the number of rows: 7
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
# *************

# %% [markdown]
# ###7. Hollow Square Pattern

# %%
n = int(input("Enter the size of square: "))

for i in range(n):
    for j in range(n):
        if i == 0 or i == n - 1 or j == 0 or j == n - 1:
            print("*", end=" ")
        else:
            print(" ", end=" ")
    print()
# Out:
# Enter the size of square: 6
# * * * * * *
# *         *
# *         *
# *         *
# *         *
# * * * * * *

# %% [markdown]
# ##Built-in Data Structures in Python:

# %% [markdown]
# ###1. Lists

# %% [markdown]
# A list is a versatile data structure that allows you to store a collection of items in a single variable. Lists can hold items of different types and are mutable, meaning their contents can be changed after creation. Here's a comprehensive guide to Python lists:

# %% [markdown]
# | List Operation  | Description                                                         | Example                                        | Output               |
# |-----------------|---------------------------------------------------------------------|------------------------------------------------|-----------------------|
# | **append()**    | Used to add an element to the end of the list.                      | `my_list = [1, 2, 3]`<br>`my_list.append(4)`    | `[1, 2, 3, 4]`       |
# | **pop()**       | Used to remove and return the last element of the list.             | `my_list = [1, 2, 3]`<br>`last_element = my_list.pop()` | `last_element = 3`  |
# | **len()**       | Used to get the length of the list.                                 | `my_list = [1, 2, 3]`<br>`length = len(my_list)`  | `length = 3`         |
# | **sort()**      | Used to sort the list in ascending order.                            | `my_list = [3, 1, 2]`<br>`my_list.sort()`          | `[1, 2, 3]`          |

# %% [markdown]
# ####Creating a list

# %%
# Empty list
empty_list = []

# List of integers
int_list = [1, 2, 3, 4, 5]

# List of strings
str_list = ["apple", "banana", "cherry"]

# List of mixed data types
mixed_list = [1, "apple", 3.14, True]

# %% [markdown]
# ####Properties of List:

# %% [markdown]
# 1. Ordered :  Lists maintain the order of elements. The order in which elements are added to the list is preserved.
#
# 2. Mutable : Lists are mutable, meaning that their elements can be changed after the list has been created.
#
# 3. Dynamic Size : Lists can grow or shrink in size as elements are added or removed.
#
# 4. Allows Duplicate Elements : Lists can contain duplicate elements.
#
# 5. Indexed : Elements in a list are accessed by their index, starting from 0.
#
# 6. Allows Mixed Data Types : Lists can contain elements of different data types.
#
# 7. Supports Nesting : Lists can contain other lists (or other complex objects), allowing for nested data structures.
#
# 8. Supports Slicing : Lists support slicing, which allows you to extract a portion of the list.
#
# 9. Iterable : Lists are iterable, meaning you can loop through the elements using a for loop or other iteration methods.
#
# 10. Supports List Comprehensions : Lists support list comprehensions, which provide a concise way to create lists.
#
# 11. Variable Length : Lists can have any number of elements, from zero to many.
#
# 12. Supports Insertion and Deletion : You can insert or delete elements at specific positions in a list.

# %% [markdown]
# ####Methods in Lists:

# %% [markdown]
# #####1. append(x) → Adds an element x at the end of the list.

# %%
fruits = ["apple", "banana", "cherry"]

fruits.append("date")
print(fruits)  # Output: ["apple", "blueberry", "cherry", "date"]
# Out:
# ['apple', 'banana', 'cherry', 'date']

# %% [markdown]
# #####2. insert(): Inserts an item at a specified position.

# %%
fruits.insert(1, "banana")
print(fruits)  # Output: ["apple", "banana", "blueberry", "cherry", "date"]
# Out:
# ['apple', 'banana', 'banana', 'banana', 'cherry', 'date']

# %% [markdown]
# #####3. remove(): Removes the first occurrence of an item.

# %%
fruits.remove("banana")
print(fruits)  # Output: ["apple", "blueberry", "cherry", "date"]
# Out:
# ['apple', 'banana', 'banana', 'cherry', 'date']

# %% [markdown]
# #####4. pop(): Removes and returns the item at a specified position (or the last item if no index is specified).

# %%
fruit = fruits.pop(1)
print(fruit)  # Output: blueberry
print(fruits)  # Output: ["apple", "cherry", "date"]
# Out:
# banana
# ['apple', 'banana', 'cherry', 'date']

# %% [markdown]
# #####5. clear(): Removes all items from the list.

# %%
fruits.clear()
print(fruits)  # Output: []
# Out:
# []

# %% [markdown]
# #####6. sort(): Sorts the list in ascending order.

# %%
numbers = [5, 2, 9, 1]
numbers.sort()
print(numbers)  # Output: [1, 2, 5, 9]
# Out:
# [1, 2, 5, 9]

# %% [markdown]
# #####7. reverse(): Reverses the order of the list.

# %%
numbers.reverse()
print(numbers)  # Output: [9, 5, 2, 1]
# Out:
# [9, 5, 2, 1]

# %% [markdown]
# #####8. count(): Returns the number of occurrences of an item.

# %%
fruit = ["apple", "banana", "cherry"]
count = fruit.count("apple")
print(count)
# Out:
# 1

# %% [markdown]
# #####9. extend(): Extends the list by appending elements from another list.

# %%
fruits.extend(["fig", "grape"])
print(fruits)  # Output: ["apple", "cherry", "date", "fig", "grape"]
# Out:
# ['apple', 'banana', 'cherry', 'fig', 'grape']

# %% [markdown]
# ###2. Strings

# %% [markdown]
# Strings are a sequence of characters used to store and manipulate text. Here are the key properties and operations associated with strings in Python:
#
# **Creating a String**
#
# * Strings can be created using single quotes, double quotes, or triple quotes (for multi-line strings):

# %%
single_quote_str = 'Hello, World!'
double_quote_str = "Hello, World!"
triple_quote_str = '''Hello,
World!'''

# %% [markdown]
# #### Properties of Strings

# %% [markdown]
# * Immutable : Strings cannot be changed after they are created. Any operation that modifies a string will create a new string.
#
# * Ordered : Strings maintain the order of characters. The order in which characters are added to the string is preserved.
#
# * Indexed : Characters in a string can be accessed by their index, starting from 0.
#
# * Iterable : Strings are iterable, meaning you can loop through each character in the string.

# %% [markdown]
# #### Strings Operations:

# %% [markdown]
# ##### 1. Concatenation (+) : Used to join two or more strings together.

# %%
s1 = "Hello"
s2 = "World"
result = s1 + " " + s2
print(result)   # Hello World
# Out:
# Hello World

# %% [markdown]
# ##### 2. Repetition (*) : Repeats a string multiple times.

# %%
word = "Hi! "
result = word * 3
print(result)   # Hi! Hi! Hi!
# Out:
# Hi! Hi! Hi!

# %% [markdown]
# ##### 3. Membership (in, not in) : Checks if a substring exists inside another string.

# %%
text = "Python Programming"
print("Python" in text)      # True
print("Java" not in text)    # True
# Out:
# True
# True

# %% [markdown]
# ##### 4. Iteration in a loop : Allows you to loop through each character in a string.

# %%
name = "Alice"
for ch in name:
    print(ch, end=" ")   # A l i c e
# Out:
# A l i c e

# %% [markdown]
# #### Methods in Strings:

# %% [markdown]
# #####1. len() - Returns the length of the string.

# %%
len("Hello")  # Output: 5
# Out:
# 5

# %% [markdown]
# #####2. str.lower() - Converts all characters in the string to lowercase.

# %%
"Hello".lower()  # Output: "hello"
# Out:
# 'hello'

# %% [markdown]
# #####3. str.upper() - Converts all characters in the string to uppercase.

# %%
"Hello".upper()  # Output: "HELLO"
# Out:
# 'HELLO'

# %% [markdown]
# #####4. str.strip() - Removes leading and trailing whitespace.

# %%
"Hello  ".strip()  # Output: "Hello"
# Out:
# 'Hello'

# %% [markdown]
# #####5. str.replace() - Replaces a substring with another substring.

# %%
"Hello, World!".replace("World", "Python")  # Output: "Hello, Python!"
# Out:
# 'Hello, Python!'

# %% [markdown]
# #####6. str.split() -Splits the string into a list of substrings based on a delimiter.

# %%
"Hello, World!".split(", ")  # Output: ["Hello", "World!"]
# Out:
# ['Hello', 'World!']

# %% [markdown]
# ##### Similarly, you can use the string functions described as follow:

# %% [markdown]
# ##### 1. Case Conversion
# - **`upper()`** → Converts all characters to uppercase.
# - **`lower()`** → Converts all characters to lowercase.
# - **`title()`** → Capitalizes the first letter of each word.
# - **`capitalize()`** → Capitalizes the first character of the string.
# - **`swapcase()`** → Swaps uppercase to lowercase and vice versa.
#
# ##### 2. Searching
# - **`find(sub)`** → Returns the index of the first occurrence of substring, or -1 if not found.
# - **`rfind(sub)`** → Returns the index of the last occurrence of substring.
# - **`index(sub)`** → Same as `find()`, but raises an error if substring not found.
# - **`count(sub)`** → Returns the number of times a substring occurs.
#
# ##### 3. Validation / Checking
# - **`isalpha()`** → Checks if all characters are alphabets.
# - **`isdigit()`** → Checks if all characters are digits.
# - **`isalnum()`** → Checks if all characters are alphanumeric (letters + digits).
# - **`isspace()`** → Checks if string contains only whitespace.
# - **`isupper()`** → Checks if all characters are uppercase.
# - **`islower()`** → Checks if all characters are lowercase.
#
# ##### 4. Modification / Trimming
# - **`strip()`** → Removes whitespace (or given characters) from both ends.
# - **`lstrip()`** → Removes whitespace from the left side.
# - **`rstrip()`** → Removes whitespace from the right side.
# - **`replace(old, new)`** → Replaces all occurrences of a substring with another.
#
# ##### 5. Splitting & Joining
# - **`split(sep)`** → Splits string into a list using the given separator.
# - **`join(iterable)`** → Joins elements of an iterable into a single string.
#
# ##### 6. Alignment & Padding
# - **`center(width, fillchar)`** → Centers string in a given width with optional fill character.
# - **`ljust(width, fillchar)`** → Left-aligns string within given width.
# - **`rjust(width, fillchar)`** → Right-aligns string within given width.
# - **`zfill(width)`** → Pads string on the left with zeros to reach specified width.
#
#
# ##### 7. String Formatting
# - **`format()`** → Inserts values into placeholders `{}` in a string.
# - **f-strings** → (Python 3.6+) Embed variables/expressions directly inside a string using `{}`.

# %% [markdown]
# ####Questions:

# %% [markdown]
# ####Q1: Check if one string is a rotation of another

# %%
s1 = "waterbottle"
s2 = "erbottlewat"

if len(s1) == len(s2) and s2 in (s1 + s1):
    print(True)
else:
    print(False)
# Out:
# True

# %% [markdown]
# ####Q2: The first non-repeating character in a string

# %%
s = "swiss"

for ch in s:
    if s.count(ch) == 1:
        print(ch)
        break
else:
    print(None)
# Out:
# w

# %% [markdown]
# ####Q3: Find the longest substring in a given string that is a palindrome.

# %%
s = "babad"
longest = ""

for i in range(len(s)):
    for j in range(i+1, len(s)+1):
        sub = s[i:j]
        if sub == sub[::-1] and len(sub) > len(longest):
            longest = sub

print(longest)   # "bab" or "aba"
# Out:
# bab

# %% [markdown]
# ####Q4: Check if two strings are isomorphic
#
# NOTE : Two strings are isomorphic if characters in one string can be replaced to get the other (mapping must be one-to-one).

# %%
s1 = "egg"
s2 = "add"

if len(s1) != len(s2):
    print(False)
else:
    pattern1 = [s1.find(ch) for ch in s1]
    pattern2 = [s2.find(ch) for ch in s2]
    print(pattern1 == pattern2)
# Out:
# True

# %% [markdown]
# ####Q5: Check if two strings are is subsequence of each other
#
# NOTE: A string s1 is a subsequence of s2 if all characters of s1 appear in s2 in the same order, but not necessarily contiguous.

# %%
s1 = "abc"
s2 = "ahbgdc"

i = 0  # pointer for s1
for ch in s2:
    if i < len(s1) and s1[i] == ch:
        i += 1

print(i == len(s1))   # True
# Out:
# True

# %% [markdown]
# ###3. Tuples:

# %% [markdown]
# A tuple is an immutable, ordered collection of elements. Tuples are similar to lists, but unlike lists, tuples cannot be changed (they are immutable).
#
# This makes them ideal for storing data that should not be modified, such as database records.
#
# **Properties :**
#
# * Ordered: Tuples maintain the order of elements, meaning the sequence in which elements are defined is preserved.
#
# * Immutable: Once a tuple is created, its elements cannot be modified, added, or removed. This immutability ensures that the data remains constant.
#
# * Allow Duplicates: Tuples can contain duplicate elements, meaning the same value can appear multiple times within the same tuple.
#
# * Indexed: Elements in a tuple can be accessed using zero-based indexing, allowing for retrieval of specific elements by their position.

# %% [markdown]
# ####Creation of Tuple:

# %% [markdown]
# Tuples are created by placing a comma-separated sequence of values inside parentheses:

# %%
my_tuple = (1, 2, 3, 'a', 'b', 'c')

# %%
my_tuple = 1, 2, 3, 'a', 'b', 'c'

# %%
single_element_tuple = (1,)

# %% [markdown]
# ####Methods in Tuples:

# %% [markdown]
# #####1. count(x): Returns the number of times the element x appears in the tuple.

# %%
my_tuple = (1, 2, 3, 2, 2, 4)
print(my_tuple.count(2))  # Output: 3
# Out:
# 3

# %% [markdown]
# #####2. index(x[, start[, end]]) :  Returns the index of the first occurrence of the element x in the tuple. The search can be limited to a specific subsequence by providing start and end indices.

# %%
my_tuple = (1, 2, 3, 2, 2, 4)
print(my_tuple.index(3))  # Output: 2
print(my_tuple.index(2, 2))  # Output: 3
# Out:
# 2
# 3

# %% [markdown]
# #####Similarly, the following kinds of functions can be used:
#
# * cmp(tuple1, tuple2)
#
# Compares elements of two different tuples.
#
# * len(tuple)
#
# Returns the length of the tuple.
#
# * max(tuple)
#
# Returns the element with the maximum value from the tuple.
#
# * min(tuple)
#
# Returns the element with the minimum value from the tuple.
#
# * tuple(seq)
#
# Returns a tuple by converting a sequence (like a list) to a tuple.

# %% [markdown]
# ####Nested Tuples:

# %% [markdown]
# Nested tuples are tuples that contain other tuples as elements. This allows for the creation of complex, multi-dimensional data structures. Here’s an overview of nested tuples, including how to create, access, and work with them:

# %%
nested_tuple = (1, (2, 3), (4, (5, 6), 7))

# %% [markdown]
# ####Iterating through Nested Tuples

# %%
for element in nested_tuple:
    if isinstance(element, tuple):
        for sub_element in element:
            print(sub_element)
    else:
        print(element)
# Out:
# 1
# 2
# 3
# 4
# (5, 6)
# 7

# %% [markdown]
# ####Converting List to a Tuple

# %%
my_list = [1, 2, 3, 4]
my_tuple = tuple(my_list)
print(my_tuple)  # Output: (1, 2, 3, 4)
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ###4. Sets:

# %% [markdown]
# A set in Python is an unordered collection of unique elements. Sets are useful for storing and manipulating collections of distinct items, and they support mathematical operations like union, intersection, and difference.

# %% [markdown]
# ####Creation of a set:

# %% [markdown]
# You can create a set using curly braces {} or the set() function.

# %%
# Using curly braces
my_set = {1, 2, 3, 4}

# Using set() function
my_set = set([1, 2, 3, 4])

# %% [markdown]
# ####Set Operations:

# %% [markdown]
# #####1. Adding and removing elements:

# %%
my_set = {1, 2, 3}
my_set.add(4)  # Adds 4 to the set
print(my_set)  # Output: {1, 2, 3, 4}
# Out:
# {1, 2, 3, 4}

# %%
my_set.remove(4)  # Removes 4 from the set

# %%
my_set.discard(4)  # Safely removes 4 from the set, if it exists

# %%
removed_element = my_set.pop()  # Removes and returns an arbitrary element

# %% [markdown]
# #####2. Union (| or .union()): Combines elements from two sets, removing duplicates.

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}
union_set = set1 | set2
print(union_set)  # Output: {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# #####3. Intersection (& or .intersection()): Finds common elements between two sets.

# %%
intersection_set = set1 & set2
print(intersection_set)  # Output: {3}
# Out:
# {3}

# %% [markdown]
# 4. Difference (- or .difference()): Finds elements present in the first set but not in the second.

# %%
difference_set = set1 - set2
print(difference_set)  # Output: {1, 2}
# Out:
# {1, 2}

# %% [markdown]
# #####5. Symmetric Difference (^ or .symmetric_difference()): Finds elements in either of the sets but not in both.

# %%
sym_diff_set = set1 ^ set2
print(sym_diff_set)  # Output: {1, 2, 4, 5}
# Out:
# {1, 2, 4, 5}

# %% [markdown]
# #####6. copy(): Returns a shallow copy of the set.

# %%
new_set = my_set.copy()

# %% [markdown]
# ###5. Dictionaries:

# %% [markdown]
# A dictionary in Python is an unordered collection of key-value pairs.
#
# Each key is unique and is used to access the corresponding value.
#
# Dictionaries are mutable, meaning you can change, add, or remove key-value pairs.
#
# **Properties :**
#
# * Unordered: Dictionaries do not maintain any order for their elements. However, from Python 3.7 onwards, dictionaries remember the insertion order of keys.
#
# * Mutable: Dictionaries can be changed after creation. You can add, modify, or remove key-value pairs.
#
# * Indexed by Keys: Values in a dictionary are accessed using keys, which are unique within the dictionary.

# %% [markdown]
# ####Creation of Dictionary:

# %%
# Using curly braces
my_dict = {'name': 'Alice', 'age': 25, 'city': 'New York'}

# Using dict() function
my_dict = dict(name='Alice', age=25, city='New York')
